# %%
Roll_No. CO2110  
Name: Aditi Vishwanath Sadalkar

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1.World Cup Matches

# %%
# using file name
import pandas as pd
df = pd.read_csv( 'WorldCupMatches.csv')
df
# Out:
#         Year              Datetime    Stage         Stadium         City  \
# 0     1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...      ...                   ...      ...             ...          ...
# 4567     NaN                   NaN      NaN             NaN          NaN
# 4568     NaN                   NaN      NaN             NaN          NaN
# 4569     NaN                   NaN      NaN             NaN          NaN
# 4570     NaN                   NaN      NaN             NaN          NaN
# 4571     NaN                   NaN      NaN             NaN          NaN
#
#      Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\archive (1)\WorldCupMatches.csv")
print(df.head())
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %% [markdown]
# # 2 liver_synthetic

# %%
#using file name
import pandas as pd
df = pd.read_csv('liver_synthetic.csv')
df
# Out:
#      Age  Gender   TB    DB  Alkpos  sgpt  sgot   TP  ALB    AG  LiverPatient
# 0     55    male  5.8  1.57     559   243   157  7.1  3.9  0.41             1
# 1     18    male  5.8  0.89      74   204    72  6.9  2.8  1.07             1
# 2     75    male  4.0  0.65     682   128   319  7.1  1.1  0.99             0
# 3     64    male  2.0  0.55     728    29   252  7.8  4.9   NaN             1
# 4     24    male  3.2  1.54     348   270   339  6.7  2.0  1.05             0
# ..   ...     ...  ...   ...     ...   ...   ...  ...  ...   ...           ...
# 198   47    male  6.9  1.31     573    68   318  5.8  2.7  1.37             1
# 199   35    male  0.2  1.18     582    81    17  8.8  3.4  0.68             1
# 200   86  female  2.3  1.02     537   265   116  7.2  1.8  0.61             0
# 201   86  female  2.3  1.02     537   265   116  7.2  1.8  0.61             0
# 202   36    male  2.1  1.20     177   218    29  4.9  2.3  0.76             1
#
# [203 rows x 11 columns]

# %%
#using file path
import pandas as pd
df = pd.read_excel(r"C:\Users\User\OneDrive\Desktop\ML\liver_synthetic.xlsx")
df
# Out:
#      Age  Gender   TB    DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0     55    Male  5.8  1.57      559   243   157  7.1  3.9  0.41             1
# 1     18    Male  5.8  0.89       74   204    72  6.9  2.8  1.07             1
# 2     75    Male  4.0  0.65      682   128   319  7.1  1.1  0.99             0
# 3     64    Male  2.0  0.55      728    29   252  7.8  4.9   NaN             1
# 4     24    Male  3.2  1.54      348   270   339  6.7  2.0  1.05             0
# ..   ...     ...  ...   ...      ...   ...   ...  ...  ...   ...           ...
# 198   47    Male  6.9  1.31      573    68   318  5.8  2.7  1.37             1
# 199   35    Male  0.2  1.18      582    81    17  8.8  3.4  0.68             1
# 200   86  Female  2.3  1.02      537   265   116  7.2  1.8  0.61             0
# 201   86  Female  2.3  1.02      537   265   116  7.2  1.8  0.61             0
# 202   36    Male  2.1  1.20      177   218    29  4.9  2.3  0.76             1
#
# [203 rows x 11 columns]

# %% [markdown]
# # 3 Advertising

# %%
#using file name
df = pd.read_csv('Advertising.csv')
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\All Datasets\Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # 4 Boston

# %%
#using file name
df = pd.read_csv('Boston.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\Boston.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # 5 claimants sample

# %%
#using file name
df = pd.read_csv('claimants sample.csv')
df
# Out:
#    CASENUM  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS  ATTORNEY
# 0        5       0       1.0         0    50.0  34.940         0
# 1        3       1       0.0         0    18.0   0.891         1
# 2       66       0       1.0         0     5.0   0.330         1
# 3       70       1       1.0         1    31.0   0.037         0
# 4       96       0       1.0         0    30.0     NaN         1
# 5       97       1       1.0         0    35.0   0.309         0
# 6       10       0       NaN         0     9.0   3.538         0
# 7       36       1       NaN         0    34.0   4.881         0
# 8       51       1       1.0         0    60.0   0.874         1
# 9       55       1       1.0         0     NaN   0.350         1

# %%
# using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\claimants sample.csv")
df
# Out:
#    CASENUM  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS  ATTORNEY
# 0        5       0       1.0         0    50.0  34.940         0
# 1        3       1       0.0         0    18.0   0.891         1
# 2       66       0       1.0         0     5.0   0.330         1
# 3       70       1       1.0         1    31.0   0.037         0
# 4       96       0       1.0         0    30.0     NaN         1
# 5       97       1       1.0         0    35.0   0.309         0
# 6       10       0       NaN         0     9.0   3.538         0
# 7       36       1       NaN         0    34.0   4.881         0
# 8       51       1       1.0         0    60.0   0.874         1
# 9       55       1       1.0         0     NaN   0.350         1

# %% [markdown]
# # 6 claimants

# %%
# using file name
df = pd.read_csv('claimants.csv')
df
# Out:
#       CASENUM  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS  ATTORNEY
# 0           5     0.0       1.0       0.0    50.0  34.940         0
# 1           3     1.0       0.0       0.0    18.0   0.891         1
# 2          66     0.0       1.0       0.0     5.0   0.330         1
# 3          70     0.0       1.0       1.0    31.0   0.037         0
# 4          96     0.0       1.0       0.0    30.0   0.038         1
# ...       ...     ...       ...       ...     ...     ...       ...
# 1335    34100     0.0       1.0       0.0     NaN   0.576         1
# 1336    34110     1.0       1.0       0.0    46.0   3.705         0
# 1337    34113     1.0       1.0       0.0    39.0   0.099         1
# 1338    34145     1.0       0.0       0.0     8.0   3.177         0
# 1339    34153     1.0       1.0       0.0    30.0   0.688         1
#
# [1340 rows x 7 columns]

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\claimants.csv")
df
# Out:
#       CASENUM  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS  ATTORNEY
# 0           5     0.0       1.0       0.0    50.0  34.940         0
# 1           3     1.0       0.0       0.0    18.0   0.891         1
# 2          66     0.0       1.0       0.0     5.0   0.330         1
# 3          70     0.0       1.0       1.0    31.0   0.037         0
# 4          96     0.0       1.0       0.0    30.0   0.038         1
# ...       ...     ...       ...       ...     ...     ...       ...
# 1335    34100     0.0       1.0       0.0     NaN   0.576         1
# 1336    34110     1.0       1.0       0.0    46.0   3.705         0
# 1337    34113     1.0       1.0       0.0    39.0   0.099         1
# 1338    34145     1.0       0.0       0.0     8.0   3.177         0
# 1339    34153     1.0       1.0       0.0    30.0   0.688         1
#
# [1340 rows x 7 columns]

# %% [markdown]
# # 7 gene_expression

# %%
#using file name
df = pd.read_csv('gene_expression.csv')
df
# Out:
#       Gene One  Gene Two  Cancer Present
# 0          4.3       3.9               1
# 1          2.5       6.3               0
# 2          5.7       3.9               1
# 3          6.1       6.2               0
# 4          7.4       3.4               1
# ...        ...       ...             ...
# 2995       5.0       6.5               1
# 2996       3.4       6.6               0
# 2997       2.7       6.5               0
# 2998       3.3       5.6               0
# 2999       4.6       8.2               0
#
# [3000 rows x 3 columns]

# %%
# using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\gene_expression.csv")
df
# Out:
#       Gene One  Gene Two  Cancer Present
# 0          4.3       3.9               1
# 1          2.5       6.3               0
# 2          5.7       3.9               1
# 3          6.1       6.2               0
# 4          7.4       3.4               1
# ...        ...       ...             ...
# 2995       5.0       6.5               1
# 2996       3.4       6.6               0
# 2997       2.7       6.5               0
# 2998       3.3       5.6               0
# 2999       4.6       8.2               0
#
# [3000 rows x 3 columns]

# %% [markdown]
# # 8 hearing_test

# %%
#using file name
df = pd.read_csv('hearing_test.csv')
df
# Out:
#        age  physical_score  test_result
# 0     33.0            40.7            1
# 1     50.0            37.2            1
# 2     52.0            24.7            0
# 3     56.0            31.0            0
# 4     35.0            42.9            1
# ...    ...             ...          ...
# 4995  73.0             3.9            0
# 4996  57.0            33.9            1
# 4997  49.0            34.5            1
# 4998  38.0            46.4            1
# 4999  48.0            38.5            1
#
# [5000 rows x 3 columns]

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\hearing_test.csv")
df
# Out:
#        age  physical_score  test_result
# 0     33.0            40.7            1
# 1     50.0            37.2            1
# 2     52.0            24.7            0
# 3     56.0            31.0            0
# 4     35.0            42.9            1
# ...    ...             ...          ...
# 4995  73.0             3.9            0
# 4996  57.0            33.9            1
# 4997  49.0            34.5            1
# 4998  38.0            46.4            1
# 4999  48.0            38.5            1
#
# [5000 rows x 3 columns]

# %% [markdown]
# # 9 homeprices

# %%
#using file name
df = pd.read_csv('homeprices.csv')
df
# Out:
#          town  area    price
# 0     Chennai  2600  5500000
# 1     Chennai  3000  5650000
# 2     Chennai  3200  6100000
# 3     Chennai  3600  6800000
# 4   Bangalore  2600  5850000
# 5   Bangalore  2800  6150000
# 6   Bangalore  3300  6500000
# 7   Bangalore  3600  7100000
# 8   Hyderabad  2600  5750000
# 9   Hyderabad  2900  6000000
# 10  Hyderabad  3100  6200000
# 11  Hyderabad  3600  6950000

# %%
# using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\homeprices.csv")
df
# Out:
#          town  area    price
# 0     Chennai  2600  5500000
# 1     Chennai  3000  5650000
# 2     Chennai  3200  6100000
# 3     Chennai  3600  6800000
# 4   Bangalore  2600  5850000
# 5   Bangalore  2800  6150000
# 6   Bangalore  3300  6500000
# 7   Bangalore  3600  7100000
# 8   Hyderabad  2600  5750000
# 9   Hyderabad  2900  6000000
# 10  Hyderabad  3100  6200000
# 11  Hyderabad  3600  6950000

# %% [markdown]
# # 10 liver_synthetic

# %%
# using file name
df = pd.read_csv('liver_synthetic.csv')
df
# Out:
#      Age  Gender   TB    DB  Alkpos  sgpt  sgot   TP  ALB    AG  LiverPatient
# 0     55    male  5.8  1.57     559   243   157  7.1  3.9  0.41             1
# 1     18    male  5.8  0.89      74   204    72  6.9  2.8  1.07             1
# 2     75    male  4.0  0.65     682   128   319  7.1  1.1  0.99             0
# 3     64    male  2.0  0.55     728    29   252  7.8  4.9   NaN             1
# 4     24    male  3.2  1.54     348   270   339  6.7  2.0  1.05             0
# ..   ...     ...  ...   ...     ...   ...   ...  ...  ...   ...           ...
# 198   47    male  6.9  1.31     573    68   318  5.8  2.7  1.37             1
# 199   35    male  0.2  1.18     582    81    17  8.8  3.4  0.68             1
# 200   86  female  2.3  1.02     537   265   116  7.2  1.8  0.61             0
# 201   86  female  2.3  1.02     537   265   116  7.2  1.8  0.61             0
# 202   36    male  2.1  1.20     177   218    29  4.9  2.3  0.76             1
#
# [203 rows x 11 columns]

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\liver.csv")
df
# Out:
#      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0     65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1     62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# ..   ...     ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60    Male   0.5  0.1      500    20    34  5.9  1.6  0.37             0
# 579   40    Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52    Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31    Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38    Male   1.0  0.3      216    21    24  7.3  4.4  1.50             0
#
# [583 rows x 11 columns]

# %% [markdown]
# # 11 liver

# %%
#using file name
df = pd.read_csv('liver.csv')
df
# Out:
#      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0     65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1     62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# ..   ...     ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60    Male   0.5  0.1      500    20    34  5.9  1.6  0.37             0
# 579   40    Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52    Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31    Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38    Male   1.0  0.3      216    21    24  7.3  4.4  1.50             0
#
# [583 rows x 11 columns]

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\liver.csv")
df
# Out:
#      Age  Gender    TB   DB  Alkphos  Sgpt  Sgot   TP  ALB    AG  LiverPatient
# 0     65  Female   0.7  0.1      187    16    18  6.8  3.3  0.90             1
# 1     62    Male  10.9  5.5      699    64   100  7.5  3.2  0.74             1
# 2     62    Male   7.3  4.1      490    60    68  7.0  3.3  0.89             1
# 3     58    Male   1.0  0.4      182    14    20  6.8  3.4  1.00             1
# 4     72    Male   3.9  2.0      195    27    59  7.3  2.4  0.40             1
# ..   ...     ...   ...  ...      ...   ...   ...  ...  ...   ...           ...
# 578   60    Male   0.5  0.1      500    20    34  5.9  1.6  0.37             0
# 579   40    Male   0.6  0.1       98    35    31  6.0  3.2  1.10             1
# 580   52    Male   0.8  0.2      245    48    49  6.4  3.2  1.00             1
# 581   31    Male   1.3  0.5      184    29    32  6.8  3.4  1.00             1
# 582   38    Male   1.0  0.3      216    21    24  7.3  4.4  1.50             0
#
# [583 rows x 11 columns]

# %% [markdown]
# # 12 mouse_viral_study

# %%
#using file name
df = pd.read_csv('mouse_viral_study.csv')
df
# Out:
#      Med_1_mL  Med_2_mL  Virus Present
# 0    6.508231  8.582531              0
# 1    4.126116  3.073459              1
# 2    6.427870  6.369758              0
# 3    3.672953  4.905215              1
# 4    1.580321  2.440562              1
# ..        ...       ...            ...
# 395  2.884122  3.271748              1
# 396  7.290855  9.488672              0
# 397  7.895325  8.272529              0
# 398  2.690592  2.674979              1
# 399  7.587821  9.473968              0
#
# [400 rows x 3 columns]

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\mouse_viral_study.csv")
df
# Out:
#      Med_1_mL  Med_2_mL  Virus Present
# 0    6.508231  8.582531              0
# 1    4.126116  3.073459              1
# 2    6.427870  6.369758              0
# 3    3.672953  4.905215              1
# 4    1.580321  2.440562              1
# ..        ...       ...            ...
# 395  2.884122  3.271748              1
# 396  7.290855  9.488672              0
# 397  7.895325  8.272529              0
# 398  2.690592  2.674979              1
# 399  7.587821  9.473968              0
#
# [400 rows x 3 columns]

# %% [markdown]
# # 13 mushrooms

# %%
#using file name
df = pd.read_csv('mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\mushrooms.csv")
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# # 14 penguins_size

# %%
#using file name
df = pd.read_csv('penguins_size.csv')
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\penguins_size.csv")
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# # 15 stroke prediction

# %%
#using file name
df = pd.read_csv('stroke prediction.csv')
df
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\stroke prediction.csv")
df
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      30669    Male   3.0             0              0           No
# 1      30468    Male  58.0             1              0          Yes
# 2      16523  Female   8.0             0              0           No
# 3      56543  Female  70.0             0              0          Yes
# 4      46136    Male  14.0             0              0           No
# ...      ...     ...   ...           ...            ...          ...
# 43395  56196  Female  10.0             0              0           No
# 43396   5450  Female  56.0             0              0          Yes
# 43397  28375  Female  82.0             1              0          Yes
# 43398  27973    Male  40.0             0              0          Yes
# 43399  36271  Female  82.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# # 16 tips

# %%
#using file name
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # 17 titanic

# %%
#using file name
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# using file path 
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 18 train_test

# %%
#using file name
df = pd.read_csv('train_test.csv')
df
# Out:
#     advitise  sales
# 0          2     15
# 1          3     17
# 2          7     12
# 3          9      8
# 4          4      3
# 5          5      4
# 6         11      6
# 7         13      8
# 8         10     13
# 9          6     17
# 10        15      4
# 11        19      3
# 12         2      8
# 13         3      1
# 14         6     14
# 15         9     17
# 16         2     14
# 17         8     16
# 18         1     11
# 19         0     12

# %%
#using file path
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\ML\train_test.csv")
df
# Out:
#     advitise  sales
# 0          2     15
# 1          3     17
# 2          7     12
# 3          9      8
# 4          4      3
# 5          5      4
# 6         11      6
# 7         13      8
# 8         10     13
# 9          6     17
# 10        15      4
# 11        19      3
# 12         2      8
# 13         3      1
# 14         6     14
# 15         9     17
# 16         2     14
# 17         8     16
# 18         1     11
# 19         0     12

# %% [markdown]
# # 19 Bahaman

# %%
# using file name 
df = pd.read_excel('Bahaman.xlsx')
df
# Out:
#      Defective     Country
# 0            0       India
# 1            0       India
# 2            0       India
# 3            0       India
# 4            1       India
# ..         ...         ...
# 795          0  Bangladesh
# 796          0  Bangladesh
# 797          1  Bangladesh
# 798          0  Bangladesh
# 799          0  Bangladesh
#
# [800 rows x 2 columns]

# %%
#using file path
df = pd.read_excel(r"C:\Users\User\OneDrive\Desktop\ML\Bahaman.xlsx")
df
# Out:
#      Defective     Country
# 0            0       India
# 1            0       India
# 2            0       India
# 3            0       India
# 4            1       India
# ..         ...         ...
# 795          0  Bangladesh
# 796          0  Bangladesh
# 797          1  Bangladesh
# 798          0  Bangladesh
# 799          0  Bangladesh
#
# [800 rows x 2 columns]

# %% [markdown]
# # 20 Bolt diameter

# %%
#using file name 
df = pd.read_excel('Bolt diameter.xlsx')
df
# Out:
#     Diameter
# 0      11.27
# 1      12.06
# 2      12.15
# 3       9.89
# 4      10.82
# 5      13.53
# 6      10.83
# 7       8.87
# 8      11.14
# 9       9.71
# 10     11.88
# 11      9.53
# 12     13.17
# 13     10.54
# 14     11.25
# 15     10.84
# 16     11.29
# 17     10.54
# 18     10.74
# 19     10.93

# %%
#using file path
df = pd.read_excel(r"C:\Users\User\OneDrive\Desktop\ML\Bolt diameter.xlsx")
df
# Out:
#     Diameter
# 0      11.27
# 1      12.06
# 2      12.15
# 3       9.89
# 4      10.82
# 5      13.53
# 6      10.83
# 7       8.87
# 8      11.14
# 9       9.71
# 10     11.88
# 11      9.53
# 12     13.17
# 13     10.54
# 14     11.25
# 15     10.84
# 16     11.29
# 17     10.54
# 18     10.74
# 19     10.93

# %% [markdown]
# # 21 Contract Renewal

# %%
#using file name 
df = pd.read_excel('Contract Renewal.xlsx')
df
# Out:
#      SupplierA  SupplierB  SupplierC
# 0         6.15       7.87       7.41
# 1         6.22       5.21       3.61
# 2         6.76       7.94       7.23
# 3         4.29       7.36       5.53
# 4         7.08       6.17       3.97
# ..         ...        ...        ...
# 115       5.85       4.53       4.27
# 116       5.04       8.06       6.39
# 117       5.68       7.14       4.60
# 118       4.77       4.84       6.15
# 119       3.57       4.55       5.28
#
# [120 rows x 3 columns]

# %%
#using file path
df = pd.read_excel(r"C:\Users\User\OneDrive\Desktop\ML\Contract Renewal.xlsx")
df
# Out:
#      SupplierA  SupplierB  SupplierC
# 0         6.15       7.87       7.41
# 1         6.22       5.21       3.61
# 2         6.76       7.94       7.23
# 3         4.29       7.36       5.53
# 4         7.08       6.17       3.97
# ..         ...        ...        ...
# 115       5.85       4.53       4.27
# 116       5.04       8.06       6.39
# 117       5.68       7.14       4.60
# 118       4.77       4.84       6.15
# 119       3.57       4.55       5.28
#
# [120 rows x 3 columns]

# %% [markdown]
# # 22 Fabric data

# %%
#using file name 
df = pd.read_excel('Fabric data.xlsx')
df
# Out:
#     Fabric_length
# 0           151.2
# 1           160.3
# 2           147.5
# 3           149.2
# 4           159.2
# 5           155.6
# 6           148.1
# 7           154.8
# 8           156.8
# 9           167.5
# 10          164.5
# 11          147.9
# 12          154.1
# 13          159.4
# 14          147.5
# 15          148.2
# 16          154.2
# 17          148.1
# 18          163.1
# 19          155.2
# 20          154.6
# 21          155.4
# 22          158.2
# 23          157.6
# 24          158.4

# %%
#using file path
df = pd.read_excel(r"C:\Users\User\OneDrive\Desktop\ML\Fabric data.xlsx")
df
# Out:
#     Fabric_length
# 0           151.2
# 1           160.3
# 2           147.5
# 3           149.2
# 4           159.2
# 5           155.6
# 6           148.1
# 7           154.8
# 8           156.8
# 9           167.5
# 10          164.5
# 11          147.9
# 12          154.1
# 13          159.4
# 14          147.5
# 15          148.2
# 16          154.2
# 17          148.1
# 18          163.1
# 19          155.2
# 20          154.6
# 21          155.4
# 22          158.2
# 23          157.6
# 24          158.4

# %% [markdown]
# # 23 JohnyTalkers

# %%
#using file name 
df = pd.read_excel('JohnyTalkers.xlsx')
df
# Out:
#         Person            Drinks
# 0       Adults  Did Not Purchase
# 1       Adults  Did Not Purchase
# 2       Adults  Did Not Purchase
# 3       Adults  Did Not Purchase
# 4       Adults  Did Not Purchase
# ...        ...               ...
# 1215  Children  Did Not Purchase
# 1216  Children  Did Not Purchase
# 1217  Children  Did Not Purchase
# 1218  Children  Did Not Purchase
# 1219  Children         Purchased
#
# [1220 rows x 2 columns]

# %%
#using file path
df = pd.read_excel(r"C:\Users\User\OneDrive\Desktop\ML\JohnyTalkers.xlsx")
df
# Out:
#         Person            Drinks
# 0       Adults  Did Not Purchase
# 1       Adults  Did Not Purchase
# 2       Adults  Did Not Purchase
# 3       Adults  Did Not Purchase
# 4       Adults  Did Not Purchase
# ...        ...               ...
# 1215  Children  Did Not Purchase
# 1216  Children  Did Not Purchase
# 1217  Children  Did Not Purchase
# 1218  Children  Did Not Purchase
# 1219  Children         Purchased
#
# [1220 rows x 2 columns]
